# %% [markdown]
# # Covid-19 cases Report

# %% [markdown]
# Coronaviruses are a large family of viruses which may cause illness in animals or humans. In humans, several coronaviruses are known to cause respiratory infections ranging from the common
# cold to more severe diseases such as Middle East Respiratory Syndrome (MERS) and Severe Acute Respiratory Syndrome (SARS). The most recently discovered coronavirus causes coronavirus disease
#  COVID-19 - World Health Organization
# The number of new cases are increasing day by day around the world.
# This dataset has information from the states and union territories of India at daily level.
#
# **Acknowledgements**
# * Thanks to Indian Ministry of Health & Family Welfare for making the data available to general public.
#
# **Task1.**
# 1. analyze covid 19 data and take insights from this data and write your report what you have taken out from it.
#
# **Task2.**
# * Show a beautiful pie chart of top seven states that have been affected by corona virus
#           1. Top seven states where active cases have been reported maximum
#           2. Top seven states where cured cases have been reported maximum
#           3. Top seven states where death cases have been reported maximum
#
# Database Link :   https://www.mohfw.gov.in/data/datanew.json

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# df = pd.read_json('datanew.json')
# df.head()
# Out:
#    sno                   state_name  active  positive    cured  death  \
# 0    1  Andaman and Nicobar Islands       0     10766    10637    129
# 1    2               Andhra Pradesh      29   2340706  2325944  14733
# 2    3            Arunachal Pradesh       0     67049    66753    296
# 3    4                        Assam       5    746170   738130   8035
# 4    5                        Bihar       4    855271   842953  12314
#
#    new_active  new_positive  new_cured  new_death death_reconsille total  \
# 0           0         10766      10637        129
# 1          32       2340709    2325944      14733
# 2           0         67049      66753        296
# 3           6        746171     738130       8035
# 4           4        855271     842953      12314
#
#    state_code  actualdeath24hrs
# 0          35                 0
# 1          28                 0
# 2          12                 0
# 3          18                 0
# 4          10                 0

# %%
df = pd.read_json("https://www.mohfw.gov.in/data/datanew.json")
df.head()
# Out:
#    sno                   state_name  active  positive    cured  death  \
# 0    1  Andaman and Nicobar Islands       0     10766    10637    129
# 1    2               Andhra Pradesh       8   2341079  2326338  14733
# 2    3            Arunachal Pradesh       0     67049    66753    296
# 3    4                        Assam       8    746225   738181   8036
# 4    5                        Bihar      11    855397   843071  12315
#
#    new_active  new_positive  new_cured  new_death death_reconsille total  \
# 0           0         10766      10637        129
# 1           6       2341079    2326340      14733
# 2           0         67049      66753        296
# 3           7        746225     738182       8036
# 4          10        855398     843073      12315
#
#    state_code  actualdeath24hrs
# 0          35                 0
# 1          28                 0
# 2          12                 0
# 3          18                 0
# 4          10                 0

# %%
df.head()
# Out:
#    sno                   state_name  active  positive    cured  death  \
# 0    1  Andaman and Nicobar Islands       0     10766    10637    129
# 1    2               Andhra Pradesh       8   2341079  2326338  14733
# 2    3            Arunachal Pradesh       0     67049    66753    296
# 3    4                        Assam       8    746225   738181   8036
# 4    5                        Bihar      11    855397   843071  12315
#
#    new_active  new_positive  new_cured  new_death death_reconsille total  \
# 0           0         10766      10637        129
# 1           6       2341079    2326340      14733
# 2           0         67049      66753        296
# 3           7        746225     738182       8036
# 4          10        855398     843073      12315
#
#    state_code  actualdeath24hrs
# 0          35                 0
# 1          28                 0
# 2          12                 0
# 3          18                 0
# 4          10                 0

# %%
df.tail()
# Out:
#     sno     state_name  active  positive     cured   death  new_active  \
# 32   33        Tripura       0    108495    107553     942           0
# 33   34    Uttarakhand       0    452588    444820    7768           0
# 34   35  Uttar Pradesh      16   2145523   2121790   23717          21
# 35   36    West Bengal      12   2126557   2104990   21555          12
# 36   37                   4170  45009713  44472153  533337        4093
#
#     new_positive  new_cured  new_death death_reconsille total  state_code  \
# 32        108495     107553        942                                 16
# 33        452588     444820       7768                                  5
# 34       2145528    2121790      23717                                  9
# 35       2126557    2104990      21555                                 19
# 36      45010242   44472756     533340                      3           0
#
#     actualdeath24hrs
# 32                 0
# 33                 0
# 34                 0
# ...

# %%
df.shape
# Out:
# (37, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sno               37 non-null     int64
#  1   state_name        37 non-null     object
#  2   active            37 non-null     int64
#  3   positive          37 non-null     int64
#  4   cured             37 non-null     int64
#  5   death             37 non-null     int64
#  6   new_active        37 non-null     int64
#  7   new_positive      37 non-null     int64
#  8   new_cured         37 non-null     int64
#  9   new_death         37 non-null     int64
#  10  death_reconsille  37 non-null     object
#  11  total             37 non-null     object
#  12  state_code        37 non-null     int64
#  13  actualdeath24hrs  37 non-null     int64
# dtypes: int64(11), object(3)
# memory usage: 4.2+ KB

# %%
df.describe()
# Out:
#              sno      active      positive         cured          death  \
# count  37.000000   37.000000  3.700000e+01  3.700000e+01      37.000000
# mean   19.000000   46.810811  2.433988e+06  2.405102e+06   28836.540541
# std    10.824355  145.034831  7.424098e+06  7.335073e+06   89396.100538
# min     1.000000    0.000000  1.076600e+04  1.063700e+04       4.000000
# 25%    10.000000    1.000000  1.085600e+05  1.076160e+05    1185.000000
# 50%    19.000000    8.000000  7.462250e+05  7.381810e+05    7768.000000
# 75%    28.000000   31.000000  1.348631e+06  1.339339e+06   14733.000000
# max    37.000000  866.000000  4.502878e+07  4.449439e+07  533476.000000
#
#        new_active  new_positive     new_cured      new_death  state_code  \
# count   37.000000  3.700000e+01  3.700000e+01      37.000000   37.000000
# mean    47.675676  2.433997e+06  2.405110e+06   28836.594595   18.324324
# std    147.646359  7.424123e+06  7.335096e+06   89396.251409   11.212726
# ...

# %%
df.head(2)
# Out:
#    sno                   state_name  active  positive    cured  death  \
# 0    1  Andaman and Nicobar Islands       0     10766    10637    129
# 1    2               Andhra Pradesh       8   2341079  2326338  14733
#
#    new_active  new_positive  new_cured  new_death death_reconsille total  \
# 0           0         10766      10637        129
# 1           6       2341079    2326340      14733
#
#    state_code  actualdeath24hrs
# 0          35                 0
# 1          28                 0

# %%
df = df.iloc[:36,1: ]
df

#use drop for s.no
# Out:
#                                   state_name  active  positive    cured  \
# 0                Andaman and Nicobar Islands       0     10766    10637
# 1                             Andhra Pradesh      29   2340706  2325944
# 2                          Arunachal Pradesh       0     67049    66753
# 3                                      Assam       5    746170   738130
# 4                                      Bihar       4    855271   842953
# 5                                 Chandigarh       2    100701    99514
# 6                               Chhattisgarh       9   1187707  1173508
# 7   Dadra and Nagar Haveli and Daman and Diu       0     11592    11588
# 8                                      Delhi      34   2041153  2014450
# 9                                       Goa*      37    263444   259393
# 10                                   Gujarat      56   1291537  1280401
# 11                                   Haryana       8   1078982  1068195
# ...

# %%
plt.figure(figsize = (20 , 20))
sns.barplot(x = df["death"] , y = df["state_name"] )
# Out:
# <Axes: xlabel='death', ylabel='state_name'>

# %%
df1=df.iloc[:,1:4]
df1.plot.barh(figsize=(20,20))
#df1=df[['active','postive','cured']]
#plt.barh(df1)
# Out:
# <Axes: >

# %%
#df = df.drop(['death_reconsille' , 'total' , 'state_code' , 'actualdeath24hrs'] , axis = 1)
df.head()
# Out:
#                     state_name  active  positive    cured  death  new_active  \
# 0  Andaman and Nicobar Islands       0     10766    10637    129           0
# 1               Andhra Pradesh       0   2340673  2325940  14733           0
# 2            Arunachal Pradesh       0     67049    66753    296           0
# 3                        Assam       2    746150   738113   8035           2
# 4                        Bihar       1    855260   842945  12314           1
#
#    new_positive  new_cured  new_death death_reconsille total  state_code  \
# 0         10766      10637        129                                 35
# 1       2340673    2325940      14733                                 28
# 2         67049      66753        296                                 12
# 3        746150     738113       8035                                 18
# 4        855260     842945      12314                                 10
#
#    actualdeath24hrs
# 0                 0
# 1                 0
# ...

# %% [markdown]
# describe each of ypur code using markdown

# %% [markdown]
# ## Approach 1

# %%
## Top seven active states
data_active = df.sort_values(["active"]  , ascending = False)
data_active = data_active.iloc[:7, :]
data_active
# Out:
#      state_name  active  positive    cured   death  new_active  new_positive  \
# 16    Kerala***    3096   6913921  6838761   72064        2954       6914274
# 15    Karnataka     436   4089587  4048785   40366         464       4089661
# 20  Maharashtra     168   8172163  8023431  148564         194       8172200
# 30   Tamil Nadu     139   3611024  3572804   38081         135       3611038
# 10      Gujarat      56   1291537  1280401   11080          59       1291546
# 31    Telangana      55    844558   840392    4111          59        844566
# 9          Goa*      37    263444   259393    4014          36        263448
#
#     new_cured  new_death death_reconsille total  state_code  actualdeath24hrs
# 16    6839256      72064                                 32                 0
# 15    4048829      40368                      2          29                 2
# 20    8023442     148564                                 27                 0
# ...

# %%
############## Pie chart for active cases########################################
explode = [0.1,0,0,0,0,0 ,0]
colors = ["c","b","y","g","r" ,"m" , "brown"]
# textprops = {"fontsize":12}
# wedgeprops = {"linewidth": 2 , "width": 1 , "edgecolor" : "black"}
# plt.figure(figsize=(16,9))
fontdict = {"fontsize":10}
plt.title("Top seven corrona affected states \n Total active cases in india  : {} \n Total active cases in these states {} \n Total percentage of active cases in these states :  {}%".format(sum(df["active"]) , sum(data_active["active"])  , round(sum(data_active["active"]) / sum(df["active"])  , 4)* 100 ), fontdict = fontdict)
#plt.pie(data_active["active"], labels = data_active["state_name"],explode = explode,colors = colors, autopct= "%0.2f%%",radius = 1,
wedgeprops = wedgeprops , textprops = textprops, pctdistance = 0.6,labeldistance = 1.1 , rotatelabels=False )

plt.pie(data_active["active"], labels = data_active["state_name"],explode = explode,colors = colors, autopct= "%0.2f%%",radius = 1,pctdistance = 0.6,labeldistance = 1.1 , rotatelabels=False )
#plt.legend(loc = 0)
plt.show()

# %%
## Top seven cured states
data_cured = df.sort_values(["cured"]  , ascending = False)
data_cured = data_cured.iloc[:7, :]
data_cured
# Out:
#         state_name  active  positive    cured   death  new_active  \
# 20     Maharashtra     168   8172163  8023431  148564         194
# 16       Kerala***    3096   6913921  6838761   72064        2954
# 15       Karnataka     436   4089587  4048785   40366         464
# 30      Tamil Nadu     139   3611024  3572804   38081         135
# 1   Andhra Pradesh      29   2340706  2325944   14733          32
# 34   Uttar Pradesh      16   2145523  2121790   23717          21
# 35     West Bengal      12   2126557  2104990   21555          12
#
#     new_positive  new_cured  new_death death_reconsille total  state_code  \
# 20       8172200    8023442     148564                                 27
# 16       6914274    6839256      72064                                 32
# 15       4089661    4048829      40368                      2          29
# 30       3611038    3572822      38081                                 33
# ...

# %%
# Top seven death states
data_death = df.sort_values(["death"]  , ascending = False)
data_death = data_death.iloc[:7, :]
data_death
# Out:
#        state_name  active  positive    cured   death  new_active  \
# 20    Maharashtra     168   8172163  8023431  148564         194
# 16      Kerala***    3096   6913921  6838761   72064        2954
# 15      Karnataka     436   4089587  4048785   40366         464
# 30     Tamil Nadu     139   3611024  3572804   38081         135
# 8           Delhi      34   2041153  2014450   26669          30
# 34  Uttar Pradesh      16   2145523  2121790   23717          21
# 35    West Bengal      12   2126557  2104990   21555          12
#
#     new_positive  new_cured  new_death death_reconsille total  state_code  \
# 20       8172200    8023442     148564                                 27
# 16       6914274    6839256      72064                                 32
# 15       4089661    4048829      40368                      2          29
# 30       3611038    3572822      38081                                 33
# 8        2041155    2014456      26669                                  7
# ...

# %% [markdown]
# ## Aproach 2

# %%
#################################################################### active case ########################

plt.subplot(3,1,1)
#plt.figure(figsize = (10 , 10))
explode =[0.1,0,0,0,0,0 ,0]
colors = ["r","b","y","g","c" ,"m" , "brown"]
textprops = {"fontsize":15}
wedgeprops = {"linewidth": 4 , "width": 1 , "edgecolor" : "k"}
plt.figure(figsize=(10,6))
fontdict = {"fontsize":10}
plt.title("Top seven corrona affected states\n Total active cases in india")
#plt.title(f"Top seven corrona affected states \n Total active cases in these states : {sum(top_seven_states_active)} \n Total active cases in india  : {sum(df["active"])} ", fontdict=fontdict)
plt.pie(data_active['active'], labels = data_active['state_name'],explode = explode,colors = colors, autopct= "%0.2f%%",radius = 1,textprops = textprops,
       pctdistance = 0.6,labeldistance = 1.1 ,wedgeprops = wedgeprops , rotatelabels=False )
#plt.legend(loc = 0)
plt.show()

######################################################################### cured_case ####################################


plt.subplot(3,1,2)
explode =[0.1,0,0,0,0,0 ,0]
colors = ["g","b","r","y","r" ,"m" , "brown"]
textprops = {"fontsize":15}
wedgeprops = {"linewidth": 4 , "width": 1 , "edgecolor" : "k"}
plt.figure(figsize=(10,6))
fontdict = {"fontsize":10}
plt.title("Top seven corrona affected states\n Total cured cases in india")
plt.pie(data_cured['cured'], labels = data_cured['state_name'],explode = explode,colors = colors, autopct= "%0.2f%%",radius = 1,textprops = textprops,
       pctdistance = 0.6,labeldistance = 1.1 ,wedgeprops = wedgeprops , rotatelabels=False )
# plt.legend(loc = 0)
plt.show()


############################################################### death cases###########################################

#plt.figure(figsize = (16,7))
plt.subplot(3,1,3)
explode =[0.1,0,0,0,0,0 ,0]
colors = ["c","b","r","g","y" ,"m" , "brown"]
textprops = {"fontsize":10}
wedgeprops = {"linewidth": 4 , "width": 1 , "edgecolor" : "k"}
plt.figure(figsize=(10,6))
fontdict = {"fontsize":10}
plt.title("Top seven corrona affected states\n Total death cases in india")
plt.pie(data_death['death'], labels = data_death['state_name'],explode = explode,colors = colors, autopct= "%0.2f%%",radius = 1,textprops = textprops,
       pctdistance = 0.6,labeldistance = 1.1 ,wedgeprops = wedgeprops , rotatelabels=False )
plt.show()
